# %% [markdown]
# <a href="https://colab.research.google.com/github/kungfumas/stbi/blob/master/snsscrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 981 kB 39.4 MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=7c3a2186652bb5762ad0c9a6962f9e33cdfde637f9017df2dfde4c22c1c049d3
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# ...

# %%
import snscrape.modules.twitter as sntwitter
import json
from langdetect import detect

# %%
keywords=['kanjuruhan']
start="2022–09–01"
end ="2022–10–03"
max_num=10000
fname='tweet.json' 
languages=['de','en']

# %%
for keyword in keywords:
   
    for i, tweet in enumerate (sntwitter.TwitterSearchScraper(f'{keyword} ').get_items()):
        
        try:
            lan=detect(tweet.content)
        except:
            lan='error'
        if i == max_num:
            break
        if lan in languages:
            data = {'id': tweet.id, 'username':tweet.username, 'date': tweet.date, 'text': tweet.content,'url':tweet.url}
            with open(fname, 'a+', encoding='utf-8') as f:
                line = json.dumps(data, ensure_ascii=False,default=str)
                print(line)
                f.write(line)
                f.write('\n')
# Out:
# {"id": 1578222455134429184, "username": "hanggapry", "date": "2022-10-07 03:15:29+00:00", "text": "So in this video, everything about Kanjuruan Disaster is clear. Indonesian Federation of Football (@PSSI ) never use regulation of Stadium and Safety Scurity from FIFA. FORGET IT ABOUT WORLD CUP U-20! PSSI Murderer! \n\n@FIFAcom please help us! #UsutSampaiTuntas #Kanjuruhan https://t.co/O43rmlD9Rv", "url": "https://twitter.com/hanggapry/status/1578222455134429184"}
# {"id": 1578221771542577152, "username": "dnkndonuts__", "date": "2022-10-07 03:12:46+00:00", "text": "@Pranadsptr @nuicemedia Pssi didnt say sorry for the death of 125 human being by police tear gas in kanjuruhan stadium", "url": "https://twitter.com/dnkndonuts__/status/1578221771542577152"}
# ...

# %% [markdown]
# https://www.freecodecamp.org/news/python-web-scraping-tutorial/
# https://medium.com/dataseries/how-to-scrape-millions-of-tweets-using-snscrape-195ee3594721
