# %% [markdown]
# <a href="https://colab.research.google.com/github/kungfumas/stbi/blob/master/serpapibaru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25789 sha256=e5696993ecb55767d79924eaa3133758f18bd457d8676975eba67b5c38b25a0e
#   Stored in directory: /root/.cache/pip/wheels/82/a3/c5/364155118f298722dff2f79ae4dd7c91e92b433ad36d6f7e0e
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_maps",
  "q": "bandeng",
  "ll": "@-6.9859048,110.3880387,13z",
  "type": "search",
  "api_key": "2b34e8b0f32ffc331e496deb6940c89f1337ea4e4d7a46e3f5e2499936353b24"
}

search = GoogleSearch(params)
results = search.get_dict()
local_results = results["local_results"]
# Out:
# https://serpapi.com/search

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Toko Bandeng Juwana Elrina',
#   'place_id': 'ChIJvRGmW0WLcC4RobMrDuHNFQA',
#   'data_id': '0x2e708b455ba611bd:0x15cde10e2bb3a1',
#   'data_cid': '6137341000004513',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b455ba611bd%3A0x15cde10e2bb3a1&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b455ba611bd%3A0x15cde10e2bb3a1&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9864215, 'longitude': 110.4132719},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b455ba611bd%3A0x15cde10e2bb3a1%218m2%213d-6.9864215%214d110.4132719&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 13528,
#   'unclaimed_listing': True,
#   'type': 'Souvenir store',
#   'address': 'Jl. Pandanaran No.57, Randusari, Semarang Selatan, Semarang City, Central Java 50244, Indonesia',
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b8f1c223fc5:0xd79d9d57c8a7d068",
  "api_key": "2b34e8b0f32ffc331e496deb6940c89f1337ea4e4d7a46e3f5e2499936353b24"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"][1]["snippet"]
# Out:
# https://serpapi.com/search

# %%
results
# Out:
# {'search_metadata': {'id': '633b93ee10d744d04b16337f',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/a5b69a9823eb8bd6/633b93ee10d744d04b16337f.json',
#   'created_at': '2022-10-04 02:01:18 UTC',
#   'processed_at': '2022-10-04 02:01:18 UTC',
#   'google_maps_reviews_url': 'https://www.google.com/async/reviewDialog?hl=en&async=feature_id:0x2e708b8f1c223fc5:0xd79d9d57c8a7d068,sort_by:,next_page_token:,associated_topic:,_fmt:pc',
#   'raw_html_file': 'https://serpapi.com/searches/a5b69a9823eb8bd6/633b93ee10d744d04b16337f.html',
#   'total_time_taken': 9.26},
#  'search_parameters': {'engine': 'google_maps_reviews',
#   'data_id': '0x2e708b8f1c223fc5:0xd79d9d57c8a7d068',
#   'hl': 'en'},
#  'place_info': {'title': 'Ikan Bakar Cianjur',
#   'address': 'Jl. Teuku Umar No.8, Jatingaleh, Kota Semarang, Jawa Tengah, Indonesia',
#   'rating': 4.5,
#   'reviews': 3147},
#  'topics': [{'keyword': 'gurame', 'mentions': 111, 'id': '/m/0803rr'},
# ...

# %%
reviews
# Out:
# "Very comfortable place, private...not too noisy...the nasi liwet was so recommended. Good for held any meeting. It has 3 floor (I guess).. the first one is the batik store... The second one is half open space and half meeting room for approximately 40 people. The third one is all open I guess(not very sure).. You can probably held a large family dinner or office gathering. Don't worry, they have elevator"
